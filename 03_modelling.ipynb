# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Collecting numpy (from xgboost)
#   Downloading numpy-2.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Using cached nvidia_nccl_cu12-2.30.7-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Collecting scipy (from xgboost)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Downloading xgboost-3.3.0-py3-none-manylinux_2_28_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 48.2 MB/s  0:00:026m0:00:0100:01
# Downloading numpy-2.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 56.9 MB/s  0:00:006m0:00:01
# Using cached nvidia_nccl_cu12-2.30.7-py3-none-manylinux_2_18_x86_64.whl (303.4 MB)
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 51.1 MB/s  0:00:006m0:00:01
# Installing collected packages: nvidia-nccl-cu12, numpy, scipy, xgboost
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [xgboost]m3/4 [xgboost]
# Successfully installed numpy-2.5.0 nvidia-nccl-cu12-2.30.7 scipy-1.18.0 xgboost-3.3.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
import xgboost as xgb

# %%
df = pd.read_csv('data/euroncap_cardata_masked.csv')
df = df[~df['stars'].isna()]
df = df.drop(columns=['type'])

# %%
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'stars', 'drive_hand', 'protocol_year',
#        'kerb_weight', 'seat_arrangement', 'rating_year',
#        'seat1_frontal_airbag', 'seat3_frontal_airbag', 'row2_frontal_airbag',
#        'seat1_pretensioner', 'seat3_pretensioner', 'row2_pretensioner',
#        'seat1_load_limiter', 'seat3_load_limiter', 'row2_load_limiter',
#        'seat1_knee_airbag', 'seat3_knee_airbag', 'seat1_side_head_airbag',
#        'seat3_side_head_airbag', 'row2_side_head_airbag',
#        'seat1_side_chest_airbag', 'seat3_side_chest_airbag',
#        'row2_side_chest_airbag', 'seat1_side_pelvis_airbag',
#        'seat3_side_pelvis_airbag', 'row2_side_pelvis_airbag',
#        'seat1_centre_lateral_airbag', 'seat3_centre_lateral_airbag',
#        'row2_centre_lateral_airbag', 'seat1_isofix', 'seat3_isofix',
#        'row2_isofix', 'row3_isofix', 'seat1_isize', 'seat3_isize',
#        'row2_isize', 'row3_isize', 'seat1_integrated_child_seat',
#        'seat3_integrated_child_seat', 'row2_integrated_child_seat',
#        'row3_integrated_child_seat', 'seat1_airbagcutoffswitch',
#        'seat3_airbagcutoffswitch', 'row2_airbagcutoffswitch',
#        'row3_airbagcutoffswitch', 'seat1_childdetection',
#        'seat3_childdetection', 'row2_childdetection', 'row3_childdetection',
#        'has_active_bonnet', 'has_aeb_vru', 'has_cyclistdoorprevention',
#        'has_aeb_m2w', 'has_aeb_cartocar', 'has_speed_assist',
#        'has_lane_assist', 'has_fatigue_detection',
#        'has_distraction_detection'],
#       dtype='str')

# %%
to_be_dropped = ['id', 'make', 'model','year', 'stars', 'protocol_year', 'seat_arrangement', 'rating_year', 'seat1_frontal_airbag', 'seat3_frontal_airbag', 'row2_frontal_airbag', 'seat1_pretensioner', 'seat3_pretensioner', 'row2_pretensioner', 'seat1_load_limiter', 'seat3_load_limiter', 'row2_load_limiter', 'seat3_knee_airbag', 'seat1_side_head_airbag', 'seat3_side_head_airbag', 'row2_side_head_airbag', 'seat1_side_chest_airbag', 'seat3_side_chest_airbag', 'row2_centre_lateral_airbag', 'seat1_isofix', 'row2_isofix', 'row3_isofix', 'seat1_integrated_child_seat','seat3_integrated_child_seat', 'row2_integrated_child_seat','row3_integrated_child_seat', 'seat1_airbagcutoffswitch','seat3_airbagcutoffswitch', 'row2_airbagcutoffswitch','row3_airbagcutoffswitch','seat1_childdetection','row3_childdetection']
features = ['kerb_weight', 'seat1_knee_airbag', 'row2_side_chest_airbag', 'seat1_side_pelvis_airbag','seat3_side_pelvis_airbag', 'row2_side_pelvis_airbag', 'seat1_centre_lateral_airbag', 'seat3_centre_lateral_airbag', 'seat3_isofix', 'seat1_isize', 'seat3_isize','row2_isize', 'row3_isize', 'seat3_childdetection', 'row2_childdetection','has_active_bonnet','has_distraction_detection', 'has_fatigue_detection', 'has_lane_assist', 'has_speed_assist', 'has_aeb_vru', 'has_cyclistdoorprevention','has_aeb_m2w', 'has_aeb_cartocar']
# df[[]].value_counts()

# %%
len(features)
# Out:
# 24

# %%
len(to_be_dropped) + len(features)
# Out:
# 61

# %%
df.shape
# Out:
# (459, 62)

# %%
df['stars'].value_counts().sort_index()
# Out:
# stars
# 1.0      3
# 2.0      4
# 3.0     32
# 4.0     89
# 5.0    331
# Name: count, dtype: int64

# %%
star_map = {1: 'low', 2:'low', 3:'low', 4:'medium', 5:'high'}
df['stars_category'] = df['stars'].map(star_map)
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'stars', 'drive_hand', 'protocol_year',
#        'kerb_weight', 'seat_arrangement', 'rating_year',
#        'seat1_frontal_airbag', 'seat3_frontal_airbag', 'row2_frontal_airbag',
#        'seat1_pretensioner', 'seat3_pretensioner', 'row2_pretensioner',
#        'seat1_load_limiter', 'seat3_load_limiter', 'row2_load_limiter',
#        'seat1_knee_airbag', 'seat3_knee_airbag', 'seat1_side_head_airbag',
#        'seat3_side_head_airbag', 'row2_side_head_airbag',
#        'seat1_side_chest_airbag', 'seat3_side_chest_airbag',
#        'row2_side_chest_airbag', 'seat1_side_pelvis_airbag',
#        'seat3_side_pelvis_airbag', 'row2_side_pelvis_airbag',
#        'seat1_centre_lateral_airbag', 'seat3_centre_lateral_airbag',
#        'row2_centre_lateral_airbag', 'seat1_isofix', 'seat3_isofix',
#        'row2_isofix', 'row3_isofix', 'seat1_isize', 'seat3_isize',
#        'row2_isize', 'row3_isize', 'seat1_integrated_child_seat',
#        'seat3_integrated_child_seat', 'row2_integrated_child_seat',
#        'row3_integrated_child_seat', 'seat1_airbagcutoffswitch',
#        'seat3_airbagcutoffswitch', 'row2_airbagcutoffswitch',
#        'row3_airbagcutoffswitch', 'seat1_childdetection',
#        'seat3_childdetection', 'row2_childdetection', 'row3_childdetection',
#        'has_active_bonnet', 'has_aeb_vru', 'has_cyclistdoorprevention',
#        'has_aeb_m2w', 'has_aeb_cartocar', 'has_speed_assist',
#        'has_lane_assist', 'has_fatigue_detection', 'has_distraction_detection',
#        'stars_category'],
#       dtype='str')

# %%
df['stars_category'].value_counts()
# Out:
# stars_category
# high      331
# medium     89
# low        39
# Name: count, dtype: int64

# %%
def map_protocol(year):
    if year <= 2019:
        return 1
    elif year <= 2021:  
        return 2
    elif year <= 2025:
        return 3
    
df['protocol_version'] = df['protocol_year'].apply(map_protocol)

# %%
features.append('protocol_version')
# features.append('stars_category')
features
# Out:
# ['kerb_weight',
#  'seat1_knee_airbag',
#  'row2_side_chest_airbag',
#  'seat1_side_pelvis_airbag',
#  'seat3_side_pelvis_airbag',
#  'row2_side_pelvis_airbag',
#  'seat1_centre_lateral_airbag',
#  'seat3_centre_lateral_airbag',
#  'seat3_isofix',
#  'seat1_isize',
#  'seat3_isize',
#  'row2_isize',
#  'row3_isize',
#  'seat3_childdetection',
#  'row2_childdetection',
#  'has_active_bonnet',
#  'has_distraction_detection',
#  'has_fatigue_detection',
#  'has_lane_assist',
#  'has_speed_assist',
#  'has_aeb_vru',
#  'has_cyclistdoorprevention',
#  'has_aeb_m2w',
#  'has_aeb_cartocar',
#  'protocol_version']

# %%
x = df[features]
y = df['stars_category']

X_train, X_test, y_train, y_test = train_test_split(
    x, y, 
    test_size=0.20, 
    random_state=42, 
    stratify=y  # Keeps the 80/20 ratio in both sets
)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (367, 25) (92, 25) (367,) (92,)

# %%
print(y_train.value_counts(normalize=True))
# Out:
# stars_category
# high      0.722071
# medium    0.193460
# low       0.084469
# Name: proportion, dtype: float64

# %%
print(y_test.value_counts(normalize=True))
# Out:
# stars_category
# high      0.717391
# medium    0.195652
# low       0.086957
# Name: proportion, dtype: float64

# %% [markdown]
# ## Random_forest - Class weight unbalanced

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# 5. Train the model on training data
model.fit(X_train, y_train)

# 6. Predict classes for the testing dataset
y_pred = model.predict(X_test)

# 7. Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%\n")
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=df['stars_category'].unique()))

# Optional: View feature importance rankings
importances = pd.Series(model.feature_importances_, index=df[features].columns)
print("Feature Importances:")
print(importances.sort_values(ascending=False))
# Out:
# Model Accuracy: 82.61%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.85      0.97      0.91        66
#          low       0.40      0.25      0.31         8
#       medium       0.83      0.56      0.67        18
#
#     accuracy                           0.83        92
#    macro avg       0.70      0.59      0.63        92
# weighted avg       0.81      0.83      0.81        92
#
# Feature Importances:
# kerb_weight                    0.375653
# seat1_centre_lateral_airbag    0.072041
# has_lane_assist                0.062947
# has_aeb_m2w                    0.041986
# has_active_bonnet              0.036678
# seat1_knee_airbag              0.033007
# has_distraction_detection      0.031535
# has_cyclistdoorprevention      0.031251
# seat1_side_pelvis_airbag       0.029901
# has_fatigue_detection          0.029359
# seat3_side_pelvis_airbag       0.027563
# seat3_isofix                   0.026458
# seat3_isize                    0.026301
# row2_childdetection            0.023589
# seat3_centre_lateral_airbag    0.023219
# row3_isize                     0.023088
# has_speed_assist               0.022702
# has_aeb_cartocar               0.021484
# row2_isize                     0.018724
# has_aeb_vru                    0.018195
# row2_side_chest_airbag         0.011267
# seat3_childdetection           0.007845
# row2_side_pelvis_airbag        0.005206
# seat1_isize                    0.000000
# dtype: float64

# %% [markdown]
# ## Retrain Model - Balanced Class weight

# %%
model = RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=100, random_state=42, class_weight='balanced')

# 5. Train the model on training data
model.fit(X_train, y_train)

# 6. Predict classes for the testing dataset
y_pred = model.predict(X_test)

# 7. Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%\n")
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=df['stars_category'].unique()))

# Optional: View feature importance rankings
importances = pd.Series(model.feature_importances_, index=df[features].columns)
print("Feature Importances:")
print(importances.sort_values(ascending=False))
# Out:
# Model Accuracy: 81.52%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.91      0.88      0.89        66
#          low       0.45      0.62      0.53         8
#       medium       0.71      0.67      0.69        18
#
#     accuracy                           0.82        92
#    macro avg       0.69      0.72      0.70        92
# weighted avg       0.83      0.82      0.82        92
#
# Feature Importances:
# kerb_weight                    0.260857
# has_lane_assist                0.125456
# seat1_centre_lateral_airbag    0.080825
# seat1_side_pelvis_airbag       0.040151
# has_active_bonnet              0.039672
# seat3_side_pelvis_airbag       0.038063
# has_aeb_vru                    0.035430
# seat3_isofix                   0.032594
# has_aeb_m2w                    0.032562
# seat3_isize                    0.032201
# has_cyclistdoorprevention      0.031613
# seat1_knee_airbag              0.030644
# has_speed_assist               0.028627
# seat3_centre_lateral_airbag    0.027331
# has_distraction_detection      0.026374
# row2_isize                     0.024735
# has_fatigue_detection          0.024652
# row2_childdetection            0.019885
# row3_isize                     0.019850
# has_aeb_cartocar               0.017396
# seat3_childdetection           0.012130
# row2_side_chest_airbag         0.011173
# row2_side_pelvis_airbag        0.007780
# seat1_isize                    0.000000
# dtype: float64

# %%
import joblib

# Save the trained model to a file
joblib.dump(model, 'euro_ncap_model.joblib')

# Load the saved model back into memory
loaded_model = joblib.load('euro_ncap_model.joblib')

# %%
model = RandomForestClassifier(max_depth=10, min_samples_split=2, n_estimators=300, random_state=42, class_weight='balanced')

# 5. Train the model on training data
model.fit(X_train, y_train)

# 6. Predict classes for the testing dataset
y_pred = model.predict(X_test)

# 7. Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%\n")
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=df['stars_category'].unique()))

# Optional: View feature importance rankings
importances = pd.Series(model.feature_importances_, index=df[features].columns)
print("Feature Importances:")
print(importances.sort_values(ascending=False))
# Out:
# Model Accuracy: 82.61%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.90      0.91      0.90        66
#          low       0.56      0.62      0.59         8
#       medium       0.69      0.61      0.65        18
#
#     accuracy                           0.83        92
#    macro avg       0.71      0.72      0.71        92
# weighted avg       0.83      0.83      0.83        92
#
# Feature Importances:
# kerb_weight                    0.298218
# has_lane_assist                0.115869
# seat1_centre_lateral_airbag    0.071179
# seat3_side_pelvis_airbag       0.039721
# has_active_bonnet              0.038289
# seat1_side_pelvis_airbag       0.035259
# has_aeb_vru                    0.034929
# seat1_knee_airbag              0.034622
# seat3_isofix                   0.032274
# seat3_isize                    0.031272
# has_cyclistdoorprevention      0.029004
# protocol_version               0.028746
# has_speed_assist               0.025756
# has_aeb_m2w                    0.025490
# row2_isize                     0.021677
# has_fatigue_detection          0.020309
# seat3_centre_lateral_airbag    0.019593
# row2_childdetection            0.018696
# row3_isize                     0.018547
# has_distraction_detection      0.018065
# has_aeb_cartocar               0.013472
# seat3_childdetection           0.010671
# row2_side_chest_airbag         0.010313
# row2_side_pelvis_airbag        0.008028
# seat1_isize                    0.000000
# dtype: float64

# %% [markdown]
# ### hyperparameter tuning

# %%
params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'class_weight': ['balanced', None]
}

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

best_model = GridSearchCV(estimator=RandomForestClassifier(random_state=42), param_grid=params, cv=5, n_jobs=-1, verbose=1, scoring='f1_macro')
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

print("Best Params:", best_model.best_params_)
print(classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best Params: {'class_weight': None, 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#         high       0.84      0.97      0.90        66
#          low       0.50      0.38      0.43         8
#       medium       0.90      0.50      0.64        18
#
#     accuracy                           0.83        92
#    macro avg       0.75      0.61      0.66        92
# weighted avg       0.82      0.83      0.81        92

# %% [markdown]
# ## random forest - using smote

# %%
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
y_train_resampled.value_counts()
# Out:
# stars_category
# high      265
# medium    265
# low       265
# Name: count, dtype: int64

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
# 5. Train the model on training data
model.fit(X_train_resampled, y_train_resampled)

# 6. Predict classes for the testing dataset
y_pred = model.predict(X_test)

# 7. Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%\n")
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=df['stars_category'].unique()))

# Optional: View feature importance rankings
importances = pd.Series(model.feature_importances_, index=df[features].columns)
print("Feature Importances:")
print(importances.sort_values(ascending=False))
# Out:
# Model Accuracy: 80.43%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.86      0.92      0.89        66
#          low       0.50      0.38      0.43         8
#       medium       0.67      0.56      0.61        18
#
#     accuracy                           0.80        92
#    macro avg       0.68      0.62      0.64        92
# weighted avg       0.79      0.80      0.79        92
#
# Feature Importances:
# kerb_weight                    0.183570
# has_lane_assist                0.151869
# seat1_centre_lateral_airbag    0.086918
# has_aeb_vru                    0.064044
# has_aeb_cartocar               0.046212
# seat3_side_pelvis_airbag       0.044782
# seat1_side_pelvis_airbag       0.041781
# has_distraction_detection      0.040026
# has_fatigue_detection          0.037753
# has_aeb_m2w                    0.035634
# has_cyclistdoorprevention      0.033276
# has_active_bonnet              0.030863
# seat3_isize                    0.030287
# seat3_isofix                   0.028890
# seat1_knee_airbag              0.028477
# has_speed_assist               0.028204
# seat3_centre_lateral_airbag    0.024224
# row2_childdetection            0.020873
# row2_isize                     0.015636
# row3_isize                     0.010193
# row2_side_chest_airbag         0.008066
# row2_side_pelvis_airbag        0.004481
# seat3_childdetection           0.003941
# seat1_isize                    0.000000
# dtype: float64

# %% [markdown]
# ## XGboost

# %%
star_map = {'low': 0, 'medium': 1, 'high': 2}
y_train_mapped = y_train.map(star_map)
y_test_mapped = y_test.map(star_map)

# %%
clf = xgb.XGBClassifier(
    n_estimators=100,      # Number of boosting rounds (trees)
    learning_rate=0.1,     # Step size shrinkage to prevent overfitting
    max_depth=5,           # Maximum depth of a tree
    tree_method="hist",    # Use histogram-based algorithm for speed
    random_state=42
)

# 5. Fit the model to the training data
clf.fit(X_train, y_train_mapped)

# 6. Predict class labels on the test data
y_pred = clf.predict(X_test)

# 7. Predict class probabilities (optional)
y_proba = clf.predict_proba(X_test)

# 8. Evaluate model performance
accuracy = accuracy_score(y_test_mapped, y_pred)
print(f"Test Accuracy: {accuracy:.4f}\n")
print("Classification Report:")
print(classification_report(y_test_mapped, y_pred))
# Out:
# Test Accuracy: 0.8261
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.38      0.40         8
#            1       0.83      0.56      0.67        18
#            2       0.86      0.95      0.91        66
#
#     accuracy                           0.83        92
#    macro avg       0.71      0.63      0.66        92
# weighted avg       0.82      0.83      0.82        92

# %% [markdown]
# ## xgboost with class balance

# %%
star_map = {'low': 0, 'medium': 1, 'high': 2}
y_train_mapped = y_train.map(star_map)
y_test_mapped = y_test.map(star_map)

# %%
import xgboost as xgb
from sklearn.utils.class_weight import compute_sample_weight

# 1. Initialize your multiclass XGBoost model
model = xgb.XGBClassifier(objective='multi:softprob', num_class=3)

# 2. Compute a weight vector matching the length of your training labels (y_train)
# 'balanced' automatically calculates weights inversely proportional to class frequencies
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_mapped)

# 3. Pass the sample weights array directly into the fit method
model.fit(X_train, y_train_mapped, sample_weight=sample_weights)

# 8. Evaluate model performance
accuracy = accuracy_score(y_test_mapped, y_pred)
print(f"Test Accuracy: {accuracy:.4f}\n")
print("Classification Report:")
print(classification_report(y_test_mapped, y_pred))
# Out:
# Test Accuracy: 0.8261
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.38      0.40         8
#            1       0.83      0.56      0.67        18
#            2       0.86      0.95      0.91        66
#
#     accuracy                           0.83        92
#    macro avg       0.71      0.63      0.66        92
# weighted avg       0.82      0.83      0.82        92

# %% [markdown]
# ## Cross validation

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced'), df[features], df['stars_category'], cv=cv, scoring='f1_macro')

print(scores)
print(f'Mean F1: {scores.mean():.4f} (+- {scores.std():.4f})')
# Out:
# [0.62525318 0.64664987 0.57696477 0.6792328  0.61576591]
# Mean F1: 0.6288 (+- 0.0339)
